# %% [markdown]
# # Project Description
# The dataset contains grades scored by students throughout their university tenure in various courses and their CGPA calculated based on their grades

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\Oscar Jacob\\Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %% [markdown]
# # Columns Description-  total 43 columns
# -Seat No : The enrolled number of candidate that took the exams
#
# CGPA : The cumulative GPA based on the four year total grade progress of each candidate . CGPA is a Final Marks -- provided to student.
#
# · All other columns are course codes in the format AB-XXX where AB are alphabets representing candidates' departments and XXX are numbers where first X represents the year the canditate took exam

# %% [markdown]
# # Predict - CGPA of a student based on different grades in four years.

# %%
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# ...

# %%
df.tail(10)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 561  CS-97562     B-      B     A-        B+     B-     B+     A-      A
# 562  CS-97563      B      B      A         C      B     B+      B     C-
# 563  CS-97564     A-      B      A        D+     B+     A-      C      A
# 564  CS-97565     A-      D      A         C     B+     B+      C     A-
# 565  CS-97566      F      F      D        C-    NaN     D+      D    NaN
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 561      B  ...     B+     B-     B+     D+     C+     B-     B+      C
# ...

# %% [markdown]
# Null values are present in the dataset

# %%
df.shape
# Out:
# (571, 43)

# %% [markdown]
# 571 rows and 43 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# Except the target column(CGPA) all the features are of object datatype

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
#Checking null values

df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']= 15
plt.rcParams['figure.figsize'] = (10,7)
plt.rcParams['figure.facecolor'] = '#FFE5B4'
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# CS-97001    1
# CS-97384    1
# CS-97378    1
# CS-97379    1
# CS-97380    1
#            ..
# CS-97185    1
# CS-97184    1
# CS-97183    1
# CS-97182    1
# CS-97571    1
# Name: Seat No., Length: 571, dtype: int64
#
#
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64
#
#
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64
#
#
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64
#
#
# A     96
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64
#
#
# A-    105
# A     100
# B-     70
# B+     62
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %% [markdown]
# # Encoding the data before treating nulls

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder

# %%
df.set_index('Seat No.',inplace= True)
df
# Out:
#          PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# Seat No.
# CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# CS-97002      A      D     D+         D     B-      C      D      A     D+
# CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# ...         ...    ...    ...       ...    ...    ...    ...    ...    ...
# CS-97567      B      A      A        A-     A+      A     A-     A-     A+
# CS-97568     A+      A      A         A      A      A      A     A-      A
# CS-97569      B      A     A-        B+      A      A      A      A      A
# CS-97570      A     B+      D         A      D     D+     B-     C-     B-
# CS-97571      C      D      D         C      C     D+      B     C+      C
#
# ...

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8744\32546335.py in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
# Define the order of the categories
categories = [['missing','WU','W','I','F', 'D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+']]

# Instantiate the encoder with the categories in reverse order
encoder = OrdinalEncoder(categories=categories)

# Select the categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Apply the encoder to each categorical column
for col in categorical_cols:
    # Fill NaN with a placeholder
    df[col] = df[col].fillna('missing')
    
    # Apply the encoder
    df[col] = encoder.fit_transform(df[[col]])

    # Replace the encoded placeholder with NaN
    if 'missing' in encoder.categories_[0]:
        df[col] = df[col].replace(list(encoder.transform([['missing']])[0]), np.nan)
df
# Out:
#           PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# Seat No.
# CS-97001     8.0     4.0     6.0        7.0     6.0     5.0     4.0     6.0
# CS-97002    12.0     3.0     5.0        4.0     9.0     7.0     4.0    13.0
# CS-97003    12.0     9.0    13.0        9.0    11.0    13.0     9.0    11.0
# CS-97004     3.0     7.0     5.0        4.0     4.0    12.0     5.0     6.0
# CS-97005    11.0    11.0    12.0       11.0    13.0    13.0    12.0    11.0
# ...          ...     ...     ...        ...     ...     ...     ...     ...
# CS-97567     9.0    12.0    13.0       12.0    14.0    13.0    12.0    12.0
# CS-97568    13.0    12.0    13.0       13.0    13.0    13.0    13.0    12.0
# CS-97569     9.0    12.0    12.0       11.0    13.0    13.0    13.0    13.0
# CS-97570    12.0    10.0     4.0       13.0     4.0     5.0     9.0     6.0
# CS-97571     6.0     3.0     4.0        7.0     7.0     5.0    10.0     8.0
#
# ...

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df.tail(10)
# Out:
#           PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# Seat No.
# CS-97562     8.0     9.0    12.0       11.0     9.0    11.0    12.0    13.0
# CS-97563     9.0     9.0    13.0        7.0    10.0    11.0    10.0     6.0
# CS-97564    11.0     9.0    13.0        5.0    11.0    12.0     7.0    13.0
# CS-97565    11.0     3.0    13.0        7.0    11.0    11.0     7.0    12.0
# CS-97566     2.0     2.0     4.0        6.0     NaN     5.0     4.0     NaN
# CS-97567     9.0    12.0    13.0       12.0    14.0    13.0    12.0    12.0
# CS-97568    13.0    12.0    13.0       13.0    13.0    13.0    13.0    12.0
# CS-97569     9.0    12.0    12.0       11.0    13.0    13.0    13.0    13.0
# CS-97570    12.0    10.0     4.0       13.0     4.0     5.0     9.0     6.0
# CS-97571     6.0     3.0     4.0        7.0     7.0     5.0    10.0     8.0
#
#           EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# Seat No.                  ...
# ...

# %%
#Treating nulls
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df1 = df
df1.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
it_impute = IterativeImputer()
df1 = pd.DataFrame(it_impute.fit_transform(df1[['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106','EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222','MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212','CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383','MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403','CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA']]), columns=['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106','EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222','MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212','CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383','MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403','CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'])

# %%
df1.tail(10)
# Out:
#      PH-121  HS-101  CY-105  HS-105/12     MT-111  CS-105  CS-106     EL-102  \
# 561     8.0     9.0    12.0       11.0   9.000000    11.0    12.0  13.000000
# 562     9.0     9.0    13.0        7.0  10.000000    11.0    10.0   6.000000
# 563    11.0     9.0    13.0        5.0  11.000000    12.0     7.0  13.000000
# 564    11.0     3.0    13.0        7.0  11.000000    11.0     7.0  12.000000
# 565     2.0     2.0     4.0        6.0   4.822115     5.0     4.0   5.677476
# 566     9.0    12.0    13.0       12.0  14.000000    13.0    12.0  12.000000
# 567    13.0    12.0    13.0       13.0  13.000000    13.0    13.0  12.000000
# 568     9.0    12.0    12.0       11.0  13.000000    13.0    13.0  13.000000
# 569    12.0    10.0     4.0       13.0   4.000000     5.0     9.0   6.000000
# 570     6.0     3.0     4.0        7.0   7.000000     5.0    10.0   8.000000
#
#      EE-119     ME-107  ...     CS-312     CS-317     CS-403     CS-421  \
# ...

# %%
df1.isnull().sum()
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # The null values have been treated

# %%
#Checking for duplicates
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicated values present

# %%
for i in df1.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 11.0    112
# 12.0    111
# 10.0     61
# 9.0      57
# 8.0      56
# 3.0      44
# 6.0      33
# 7.0      31
# 4.0      22
# 13.0     22
# 5.0      19
# 0.0       2
# 2.0       1
# Name: PH-121, dtype: int64
#
#
# 11.0    82
# 8.0     78
# 6.0     68
# 9.0     63
# 10.0    59
# 5.0     50
# 7.0     47
# 3.0     45
# 12.0    38
# 4.0     36
# 13.0     4
# 2.0      1
# Name: HS-101, dtype: int64
#
#
# 13.0    177
# 12.0    120
# 11.0     50
# 10.0     49
# 9.0      42
# 4.0      31
# 14.0     31
# 7.0      19
# 8.0      17
# 6.0      16
# 5.0      14
# 1.0       3
# 3.0       1
# Name: CY-105, dtype: int64
#
#
# 13.0    96
# 12.0    75
# 11.0    70
# 10.0    57
# 4.0     45
# 7.0     41
# 9.0     40
# 8.0     39
# 6.0     36
# 5.0     34
# 14.0    34
# 1.0      2
# 3.0      1
# Name: HS-105/12, dtype: int64
#
#
# 12.0    105
# 13.0    100
# 9.0      70
# 11.0     62
# 10.0     55
# 6.0      39
# 8.0      33
# 7.0      30
# 4.0      26
# 14.0     23
# 5.0      21
# 1.0       3
# ...

# %%
df1.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     9.024518    7.809107   10.796441    9.632947    9.950658   10.994746
# std      2.957493    2.724223    2.829126    3.116436    2.866136    2.500872
# min      0.000000    2.000000    1.000000    1.000000    1.000000    4.000000
# 25%      7.000000    6.000000    9.000000    7.000000    8.000000   10.000000
# 50%     10.000000    8.000000   12.000000   10.000000   11.000000   12.000000
# 75%     11.000000   10.000000   13.000000   12.000000   12.000000   13.000000
# max     13.000000   13.000000   14.000000   14.000000   14.000000   14.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     9.822256    9.904669   10.002189    9.053725  ...   10.860944
# ...

# %%
df1.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.408428  0.633483   0.558029  0.512023  0.673658
# HS-101     0.408428  1.000000  0.363589   0.492469  0.472903  0.444827
# CY-105     0.633483  0.363589  1.000000   0.586902  0.589405  0.623756
# HS-105/12  0.558029  0.492469  0.586902   1.000000  0.533677  0.547856
# MT-111     0.512023  0.472903  0.589405   0.533677  1.000000  0.451065
# CS-105     0.673658  0.444827  0.623756   0.547856  0.451065  1.000000
# CS-106     0.322966  0.370265  0.421264   0.538728  0.566065  0.320588
# EL-102     0.442261  0.385138  0.496217   0.381785  0.580549  0.378720
# EE-119     0.665107  0.328399  0.560048   0.472048  0.453879  0.603300
# ME-107     0.579723  0.370463  0.490698   0.390471  0.498928  0.504331
# CS-107     0.534502  0.525447  0.534246   0.580882  0.521230  0.558005
# HS-205/20  0.343982  0.209329  0.336335   0.231225  0.365140  0.225590
# ...

# %% [markdown]
# # Observations:
#
# The CGPA has a strong positive correlation with all the courses, which is expected. Normally, we would expect a positive correlation, i.e., students who score higher in courses tend to have a higher CGPA.
#
# The courses MT-224, CS-210, CS-214, EE-217, CS-212 have a high positive correlation with the CGPA. This implies that students who scored higher in these courses tend to have a higher CGPA.
#
# Some courses like PH-121, CY-105, MT-111, CS-105, EE-119, ME-107, MT-222, EE-222, CS-210, CS-211, CS-203, CS-214, EE-217, CS-212 are highly correlated with each other. This could imply that students who perform well in one of these courses also tend to perform well in the others.
#
# Some courses like CS-106, EL-102, HS-205/20, MT-331, EF-303, HS-304, CS-301, CS-302, TC-383, MT-442, EL-332, CS-318, CS-306, CS-312, CS-317, CS-403, CS-421, CS-406, CS-414, CS-419, CS-423, CS-412 have a lower correlation with the CGPA. This could imply that these courses have less impact on the CGPA.

# %% [markdown]
# # Feature Scaling

# %%
for i in df1.columns:
    plt.hist(df1[i],bins = 30)
    plt.show()

# %%
#seperating features and target variables
y = df1['CGPA']
X = df1.drop('CGPA', axis = 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(X),columns = X.columns)
x
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0   -0.346718 -1.399462 -1.696866  -0.845599 -1.379600 -2.399165 -2.270876
# 1    1.006964 -1.766861 -2.050642  -1.809081 -0.331977 -1.598742 -2.270876
# 2    1.006964  0.437533  0.779566  -0.203278  0.366438  0.802525 -0.320707
# 3   -2.038821 -0.297265 -2.050642  -1.809081 -2.078016  0.402314 -1.880842
# 4    0.668544  1.172331  0.425790   0.439044  1.064854  0.802525  0.849394
# ..        ...       ...       ...        ...       ...       ...       ...
# 566 -0.008298  1.539730  0.779566   0.760204  1.414062  0.802525  0.849394
# 567  1.345385  1.539730  0.779566   1.081365  1.064854  0.802525  1.239427
# 568 -0.008298  1.539730  0.425790   0.439044  1.064854  0.802525  1.239427
# 569  1.006964  0.804932 -2.404418   1.081365 -2.078016 -2.399165 -0.320707
# 570 -1.023560 -1.766861 -2.404418  -0.845599 -1.030393 -2.399165  0.069326
#
# ...

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF Values   Features
# 0     3.587910     PH-121
# 1     1.991162     HS-101
# 2     3.024041     CY-105
# 3     2.720942  HS-105/12
# 4     3.069236     MT-111
# 5     2.902614     CS-105
# 6     2.462491     CS-106
# 7     2.308390     EL-102
# 8     2.653677     EE-119
# 9     2.536978     ME-107
# 10    2.779427     CS-107
# 11    1.806561  HS-205/20
# 12    2.575312     MT-222
# 13    2.778416     EE-222
# 14    3.554275     MT-224
# 15    4.314123     CS-210
# 16    3.214009     CS-211
# 17    3.040657     CS-203
# 18    3.233643     CS-214
# 19    3.130218     EE-217
# 20    3.683895     CS-212
# 21    3.600836     CS-215
# 22    2.307137     MT-331
# 23    2.669142     EF-303
# 24    3.249935     HS-304
# 25    4.121388     CS-301
# 26    3.344910     CS-302
# 27    3.671929     TC-383
# 28    2.472318     MT-442
# 29    4.118274     EL-332
# 30    2.769279     CS-318
# 31    4.864229     CS-306
# 32    4.188059     CS-312
# 33    4.452956     CS-317
# ...

# %% [markdown]
# From the VIF values provided, it appears that the feature CS-412 has the highest VIF value of 5.807421, indicating that it might be highly correlated with other features. Features CS-306, CS-312, CS-317, CS-210, CS-406, and CS-421 also have VIF values greater than 4, suggesting potential multicollinearity.

# %%
x.drop('CS-412',axis = 1,inplace = True)

# %%
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF Values   Features
# 0     3.530579     PH-121
# 1     1.983586     HS-101
# 2     3.000361     CY-105
# 3     2.682887  HS-105/12
# 4     3.040350     MT-111
# 5     2.887539     CS-105
# 6     2.445383     CS-106
# 7     2.299384     EL-102
# 8     2.577031     EE-119
# 9     2.536940     ME-107
# 10    2.775233     CS-107
# 11    1.802184  HS-205/20
# 12    2.563141     MT-222
# 13    2.774519     EE-222
# 14    3.547062     MT-224
# 15    4.302382     CS-210
# 16    3.211542     CS-211
# 17    3.027186     CS-203
# 18    3.229216     CS-214
# 19    3.097605     EE-217
# 20    3.683571     CS-212
# 21    3.600678     CS-215
# 22    2.299115     MT-331
# 23    2.608856     EF-303
# 24    3.229192     HS-304
# 25    4.118460     CS-301
# 26    3.238910     CS-302
# 27    3.585471     TC-383
# 28    2.345252     MT-442
# 29    4.107138     EL-332
# 30    2.768575     CS-318
# 31    4.831704     CS-306
# 32    4.187682     CS-312
# 33    4.448745     CS-317
# ...

# %%
x.drop('CS-306',axis = 1,inplace = True)

# %%
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF Values   Features
# 0     3.526141     PH-121
# 1     1.982597     HS-101
# 2     2.998872     CY-105
# 3     2.587862  HS-105/12
# 4     3.027882     MT-111
# 5     2.887505     CS-105
# 6     2.442820     CS-106
# 7     2.299069     EL-102
# 8     2.563922     EE-119
# 9     2.533984     ME-107
# 10    2.727843     CS-107
# 11    1.802130  HS-205/20
# 12    2.542391     MT-222
# 13    2.759511     EE-222
# 14    3.529064     MT-224
# 15    4.251829     CS-210
# 16    3.186819     CS-211
# 17    3.023884     CS-203
# 18    3.228628     CS-214
# 19    3.061860     EE-217
# 20    3.677112     CS-212
# 21    3.598416     CS-215
# 22    2.281638     MT-331
# 23    2.594305     EF-303
# 24    3.223223     HS-304
# 25    4.052599     CS-301
# 26    3.152335     CS-302
# 27    3.475171     TC-383
# 28    2.344130     MT-442
# 29    3.987060     EL-332
# 30    2.767091     CS-318
# 31    4.146252     CS-312
# 32    4.065847     CS-317
# 33    3.216568     CS-403
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRs = 0
for i in range(1,2000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i 
print('Best r2 score is =', maxAccu,'at random state =', maxRS )
# Out:
# Best r2 score is = 0.9935213073425894 at random state = 1584

# %%
#Creating train and test split at random state = 1584
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = maxRS)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
import xgboost as xgb

# %%
#linear Regression
lr = LinearRegression()
lr.fit(x_train,y_train)
pred_LR =lr.predict(x_test)
pred_train = lr.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 99.35213073425894
# R2 score on training data : 97.26029797987238
# Mean Absolute Error : 0.03790658348097067
# Mean Sqaured Error : 0.0023979632301803725
# Root Mean Squared Error : 0.04896900274847725

# %%
#XG boost
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_LR =xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
# Out:
# R2 score : 95.27901423872336
# R2 score on training data : 99.99983179266188
# Mean Absolute Error : 0.09901099235512491
# Mean Sqaured Error : 0.017473818969938607

# %%
#random Forest Regressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred_LR =rf.predict(x_test)
pred_train = rf.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 96.32681279363936
# R2 score on training data : 99.11552954326733
# Mean Absolute Error : 0.08542430232558142
# Mean Sqaured Error : 0.013595594549999986
# Root Mean Squared Error : 0.11660014815599501

# %%
#KNN
kn = KNN()
kn.fit(x_train,y_train)
pred_LR =kn.predict(x_test)
pred_train = kn.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 97.01220278594947
# R2 score on training data : 96.38114757531315
# Mean Absolute Error : 0.07866162790697677
# Mean Sqaured Error : 0.01105875558139535
# Root Mean Squared Error : 0.10516061801546885

# %%
#Gradient Boosting Regressor
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred_LR =gb.predict(x_test)
pred_train = gb.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 97.94279488245795
# R2 score on training data : 99.76988512305608
# Mean Absolute Error : 0.06580766140077599
# Mean Sqaured Error : 0.007614348279296706
# Root Mean Squared Error : 0.08726023309215204

# %%
#lasso
lasso = Lasso()
lasso.fit(x_train,y_train)
pred_LR =lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : -0.9934918391334202
# R2 score on training data : 0.0
# Mean Absolute Error : 0.5241748994579472
# Mean Sqaured Error : 0.3738079466398919
# Root Mean Squared Error : 0.6113983534815022

# %%
#Ridge
rd = Ridge()
rd.fit(x_train,y_train)
pred_LR =rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 99.35485923754287
# R2 score on training data : 97.26027702212096
# Mean Absolute Error : 0.037824213264810835
# Mean Sqaured Error : 0.002387864201110332
# Root Mean Squared Error : 0.048865777402087154

# %%
#Decision Tree
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
pred_LR =dt.predict(x_test)
pred_train = dt.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 79.7219195040523
# R2 score on training data : 100.0
# Mean Absolute Error : 0.21551162790697673
# Mean Sqaured Error : 0.07505540697674418
# Root Mean Squared Error : 0.2739624189131498

# %%
#SVR
from sklearn.svm import SVR
sv = SVR()
sv.fit(x_train,y_train)
pred_LR =sv.predict(x_test)
pred_train = sv.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 98.41209595544818
# R2 score on training data : 98.88410704375849
# Mean Absolute Error : 0.058578004028622586
# Mean Sqaured Error : 0.005877320801032965
# Root Mean Squared Error : 0.07666368632561942

# %%
#Extra Trees
from sklearn.ensemble import ExtraTreesRegressor
et = ExtraTreesRegressor()
et.fit(x_train,y_train)
pred_LR =et.predict(x_test)
pred_train = et.predict(x_train)
print('R2 score :', r2_score(y_test,pred_LR)*100)
print('R2 score on training data :', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred_LR))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score : 97.58615347354609
# R2 score on training data : 100.0
# Mean Absolute Error : 0.07027529069767445
# Mean Sqaured Error : 0.00893438772267441
# Root Mean Squared Error : 0.09452189017721985

# %% [markdown]
# # Cross validation score

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(lr,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.96105364 0.96531466 0.98191026 0.98889563 0.97043675]
# 0.9735221901014391
# Difference between  R2 score and  cross validation score is = 0.2339344634021745

# %%
score = cross_val_score(xgb,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.90706128 0.94863501 0.95023297 0.91634649 0.91931498]
# 0.9283181461020942
# Difference between  R2 score and  cross validation score is = 4.754338863336671

# %%
score = cross_val_score(rf,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.90960769 0.94102999 0.96260769 0.94873596 0.9351541 ]
# 0.9394270854190723
# Difference between  R2 score and  cross validation score is = 3.6434449316388617

# %%
score = cross_val_score(kn,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.95654942 0.94717126 0.95977283 0.95242719 0.94313823]
# 0.9518117858155964
# Difference between  R2 score and  cross validation score is = 2.4049748919864444

# %%
score = cross_val_score(gb,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.93763665 0.96038765 0.96793305 0.97074767 0.95545479]
# 0.9584319619952769
# Difference between  R2 score and  cross validation score is = 1.7429572740183974

# %%
score = cross_val_score(lasso,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [-0.00643799 -0.0037979  -0.00364638 -0.00242138 -0.02411396]
# -0.008083520623131602
# Difference between  R2 score and  cross validation score is = 98.39450553585924

# %%
score = cross_val_score(rd,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.96108741 0.96533127 0.98197062 0.98894367 0.97048487]
# 0.9735635674031119
# Difference between  R2 score and  cross validation score is = 0.22979673323489935

# %%
score = cross_val_score(dt,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.75540933 0.82948107 0.89086249 0.82170485 0.8083129 ]
# 0.8211541266483546
# Difference between  R2 score and  cross validation score is = 15.470740808710627

# %%
score = cross_val_score(sv,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.97229402 0.97045855 0.96846381 0.97353669 0.96078346]
# 0.9691073044606702
# Difference between  R2 score and  cross validation score is = 0.6754230274790718

# %%
score = cross_val_score(et,x,y,cv = 5, scoring = 'r2')
print(score)
print(score.mean())
print('Difference between  R2 score and  cross validation score is =', (r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.94990322 0.95919495 0.97157903 0.96276373 0.93861567]
# 0.9564113190499534
# Difference between  R2 score and  cross validation score is = 1.9450215685507533

# %% [markdown]
# # from all the scores we are going to select Linear regression as our final model

# %%
lr.fit(x_train,y_train)
pred =lr.predict(x_test)
print('R2 score :', r2_score(y_test,pred)*100)
print('Mean Absolute Error :', mean_absolute_error(y_test,pred))
print('Mean Sqaured Error :', mean_squared_error(y_test,pred))
print('Root Mean Squared Error :', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score : 99.35213073425894
# Mean Absolute Error : 0.03790658348097067
# Mean Sqaured Error : 0.0023979632301803725
# Root Mean Squared Error : 0.04896900274847725

# %%
#Saving the model
import pickle
filename = 'SGP.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
import pickle
loaded_model = pickle.load(open('SGP.pkl','rb'))
prediction = loaded_model.predict(x_test)
prediction
# Out:
# array([2.84923674, 3.95209818, 3.35133975, 2.31481066, 2.98084086,
#        2.79484026, 2.72015213, 2.37289185, 2.51553872, 3.77191973,
#        2.61367081, 2.9528369 , 3.72381016, 3.33221379, 3.21543904,
#        3.45230858, 2.72432478, 2.89984308, 3.00021828, 3.3917382 ,
#        3.64219722, 3.57695504, 3.48119121, 3.7911421 , 2.73071728,
#        3.7761555 , 2.06786092, 3.55117685, 2.76884058, 3.39151253,
#        2.2312792 , 3.95540586, 1.99888553, 2.77222504, 3.8338853 ,
#        2.66601606, 3.80142676, 3.24051521, 3.35148625, 3.45429601,
#        1.89523912, 1.994784  , 2.10754968, 3.85864193, 3.22802249,
#        2.43787875, 3.62961565, 3.36580186, 2.62800116, 3.74286581,
#        1.99686516, 3.12464795, 3.72093112, 2.75510172, 3.01291672,
#        2.12578673, 3.32069679, 2.50208944, 2.60792873, 2.34575208,
#        3.08980804, 3.5574515 , 3.29161277, 1.98191985, 3.25559232,
#        2.63214596, 2.99288461, 3.11222418, 2.97739384, 3.82491152,
# ...

# %%
a = np.array(y_test)
df = pd.DataFrame()
df['Predicted'] = prediction
df['Original'] = a
df
# Out:
#      Predicted  Original
# 0     2.849237     2.895
# 1     3.952098     3.882
# 2     3.351340     3.416
# 3     2.314811     2.350
# 4     2.980841     3.058
# ..         ...       ...
# 167   3.944423     3.897
# 168   2.370693     2.363
# 169   2.442120     2.444
# 170   2.732406     2.699
# 171   3.593544     3.662
#
# [172 rows x 2 columns]
